# %% [markdown]
# # Classification of handwritten digits using various neural network models with PyTorch
# * Multinomial classification task of images of handwritten digits (10 classes).
# * The database has a training set of 60k examples, and a test set of 10k examples, each image is of 28x28 pixels size.
# * The MNIST ("Modified National Institute of Standards and Technology") is the “hello world” dataset for computer vision. Since its release in 1999, this classic dataset of handwritten images has served as the basis for benchmarking classification algorithms.

# %% [markdown]
# ## Model setup

# %% [markdown]
# Before we start we need to load libraries and setup the model parameters

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 14})

model_args = {}
# random seed
model_args['seed'] = 123
# we will use batch size of 128 in Stochastic Gradient Descent (SGD) optimization of the network
model_args['batch_size'] = 128
# learning rate is how fast it will descend
model_args['lr'] = .05
# SGD momentum (default: .5) momentum is a moving average of gradients (it helps to keep direction)
model_args['momentum'] = .5
# the number of epochs is the number of times you go through the full dataset
model_args['epochs'] = 50
# logging frequency
model_args['log_interval'] = 100

# %% [markdown]
# Let's start with loading the dataset and check how it looks like
# > **In case of problems with downloading dataset via torchvison please use the second method**

# %%
# load the MINST dataset via torchvision
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.1307,), (0.3081,))])
mnist_train = datasets.MNIST('../data', train=True, download=True, transform=transform)
# we divide this data into training and validation subsets
train_subset, validation_subset = torch.utils.data.random_split(mnist_train, [50000, 10000])
test_subset = datasets.MNIST('../data', train=False, download=True, transform=transform)

# %% [markdown]
# Second method: directly download tar.gz archive

# %%
# alternatively just download MNIST.tar.gz archive
# !wget www.di.ens.fr/~lelarge/MNIST.tar.gz
# !tar -zxvf MNIST.tar.gz

transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.1307,), (0.3081,))])
mnist_train = datasets.MNIST('./', train=True, download=False, transform=transform)
# we divide this data into training and validation subsets
train_subset, validation_subset = torch.utils.data.random_split(mnist_train, [50000, 10000])
test_subset = datasets.MNIST('./', train=False, download=False, transform=transform)

# %%
# define dataloaders
loader_kwargs = {'batch_size': model_args['batch_size'],
                 'num_workers': 2,
                 'pin_memory': True,
                 'shuffle': True}
train_loader = torch.utils.data.DataLoader(train_subset, **loader_kwargs)
validation_loader = torch.utils.data.DataLoader(validation_subset, **loader_kwargs)
test_loader = torch.utils.data.DataLoader(test_subset, **loader_kwargs)

# %% [markdown]
# Plot sample images

# %%
print(len(train_subset))
print(len(validation_subset))
print(len(test_subset)) # we have data already divided into train & validation & test subsets
print(len(train_loader)) # no of train batches
example_number = 123
print(train_subset[example_number][0][0].shape) # single item shape

fig, axs = plt.subplots(5, 5, figsize=(7,7), tight_layout=True)
for i in range(5):
    for j in range(5):
        axs[i,j].imshow(train_subset[example_number+i*5+j][0].reshape(28,28), cmap='gray')
        axs[i,j].set_title(train_subset[example_number+i*5+j][1])
# Out:
# 50000
# 10000
# 10000
# 391
# torch.Size([28, 28])

# %% [markdown]
# Let's now construct the NN models:
# - we start with siplest single layer **perceptron** with *softmax* activation,
# - then test **deep** network with some (fully-connected) *hidden* layers,
# - and finally setup deep **convolutional neural network**.

# %%
class Perceptron(nn.Module):
    # this defines the structure of the Perceptron model
    def __init__(self):
        super(Perceptron, self).__init__()
        # fully connected layer
        self.fc = nn.Linear(28*28, 10)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc(x)
        return F.log_softmax(x, dim=1) # note that dim=0 is the number of samples in batch

class Deep(nn.Module):
    # this defines the structure of the Perceptron model
    def __init__(self):
        super(Deep, self).__init__()
        # fully connected layers
        self.fc1 = nn.Linear(28*28, 20)
        self.fc2 = nn.Linear(20, 10)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = F.relu(x)
        # hidden layer
        x = self.fc2(x)
        return F.log_softmax(x, dim=1) # note that dim=0 is the number of samples in batch

class CNN(nn.Module):
    # this defines the structure of the CNN model
    def __init__(self):
        super(CNN, self).__init__()
        # convolutional layer with 2 kernels of size 5x5
        self.conv1 = nn.Conv2d(1, 2, kernel_size=5)
        # 4 kernels of size 5x5
        self.conv2 = nn.Conv2d(2, 4, kernel_size=5)
        # 2D dropout
        self.conv2_drop = nn.Dropout2d()
        # fully connected layers
        self.fc1 = nn.Linear(64, 20)
        self.fc2 = nn.Linear(20, 10)

    def forward(self, x):
        # 1st layers group
        x = self.conv1(x) # resulting in 2 feature maps each of size 24x24
        x = F.max_pool2d(x, 2) # downsizing each map to 12x12
        x = F.relu(x) # standard (in CNNs) ReLU activation
        # 2nd group
        x = self.conv2(x) # resulting in 4 feature maps each of size 8x8
        # x = self.conv2_drop(x)
        x = F.max_pool2d(x, 2) # downsizing each map to 4x4
        x = F.relu(x)
        # fully connected layers
        x = x.view(-1, 64) # 4 maps of 4x4 size gives 64 numbers
        x = self.fc1(x) # 64 -> 20
        x = F.relu(x)
        x = F.dropout(x, training=self.training) # dropout is a type of regularization
        x = self.fc2(x) # 20 -> 10
        # softmax (multinomial classification) gives probabilities of each class
        return F.log_softmax(x, dim=1) # note that dim=0 is the number of samples in batch

# %% [markdown]
# And define training, testing, and plotting utils:

# %%
def train(model, device, train_loader, optimizer, epoch_number):
    model.train()
    train_loss = 0.
    # get subsequent batches over the data in a given epoch
    for batch_idx, (data, target) in enumerate(train_loader):
        # send data tensors to GPU (or CPU)
        data, target = data.to(device), target.to(device)
        # this will zero out the gradients for this batch
        optimizer.zero_grad()
        # this will execute the forward() function
        output = model(data)
        # calculate the negative-log-likelihood loss
        loss = F.nll_loss(output, target, reduction='mean')
        # backpropagate the loss
        loss.backward()
        # update the model weights (with assumed learning rate)
        optimizer.step()
        if batch_idx % model_args['log_interval'] == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch_number, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
        train_loss += loss.item()
    train_loss /= len(train_loader)
    print('\nTrain set: Average loss: {:.4f}'.format(train_loss))
    return train_loss

def test(model, device, test_loader, message):
    model.eval()
    test_loss = 0.
    correct = 0
    # this is just inference, we don't need to calculate gradients
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            # calculate and sum up batch loss
            test_loss += F.nll_loss(output, target, reduction='mean')
            # get the index of class with the max log-probability
            prediction = output.argmax(dim=1)
            # item() returns value of the given tensor
            correct += prediction.eq(target).sum().item()
    test_loss /= len(test_loader)
    print('{}: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        message, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss.cpu()

def plot_loss(train_loss, validation_loss, title):
    plt.grid(True)
    plt.xlabel("subsequent epochs")
    plt.ylabel('average loss')
    plt.plot(range(1, len(train_loss)+1), train_loss, 'o-', label='training')
    plt.plot(range(1, len(validation_loss)+1), validation_loss, 'o-', label='validation')
    plt.legend()
    plt.title(title)
    plt.show()

# %% [markdown]
# ## Experiments

# %% [markdown]
# 1. At first let's test the single-layer *Perceptron* model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Perceptron().to(device)

optimizer = optim.SGD(model.parameters(), lr=model_args['lr'], momentum=model_args['momentum'])
#optimizer = optim.Adadelta(model.parameters(), lr=model_args['lr'])

torch.manual_seed(model_args['seed'])
train_loss = []
validation_loss = []
for epoch_number in range(1, model_args['epochs'] + 1):
    train_loss.append(train(model, device, train_loader, optimizer, epoch_number))
    validation_loss.append(test(model, device, validation_loader, 'Validation set'))

test(model, device, test_loader, 'Test set')
plot_loss(train_loss, validation_loss, 'Perceptron model')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.458467
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 0.249378
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.418440
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.350050
#
# Train set: Average loss: 0.3770
# Validation set: Average loss: 0.3107, Accuracy: 9096/10000 (91%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.249111
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.275108
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.226705
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.183137
#
# Train set: Average loss: 0.3045
# Validation set: Average loss: 0.2982, Accuracy: 9161/10000 (92%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.198597
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.270914
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.331941
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.239124
#
# Train set: Average loss: 0.2907
# Validation set: Average loss: 0.3012, Accuracy: 9152/10000 (92%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.233725
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.283069
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.247274
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.328126
#
# Train set: Average loss: 0.2837
# Validation set: Average loss: 0.2815, Accuracy: 9208/10000 (92%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.111980
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.245719
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.276205
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.446746
#
# Train set: Average loss: 0.2790
# Validation set: Average loss: 0.2926, Accuracy: 9183/10000 (92%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.172213
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 0.274231
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.206455
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.403063
#
# Train set: Average loss: 0.2752
# Validation set: Average loss: 0.2841, Accuracy: 9204/10000 (92%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.301551
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.297022
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.118289
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.223133
#
# Train set: Average loss: 0.2708
# Validation set: Average loss: 0.2923, Accuracy: 9179/10000 (92%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.212956
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.258897
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.251052
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.344113
#
# Train set: Average loss: 0.2689
# Validation set: Average loss: 0.2884, Accuracy: 9206/10000 (92%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.275197
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.440754
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.328586
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.279350
#
# Train set: Average loss: 0.2668
# Validation set: Average loss: 0.2884, Accuracy: 9206/10000 (92%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.175676
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.314794
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.495057
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.402915
#
# Train set: Average loss: 0.2653
# Validation set: Average loss: 0.2875, Accuracy: 9194/10000 (92%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.367479
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.265571
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.230355
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.240430
#
# Train set: Average loss: 0.2634
# Validation set: Average loss: 0.2875, Accuracy: 9192/10000 (92%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.267786
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.182816
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.143017
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.347714
#
# Train set: Average loss: 0.2622
# Validation set: Average loss: 0.2845, Accuracy: 9207/10000 (92%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.244065
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.289403
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.341473
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.187331
#
# Train set: Average loss: 0.2598
# Validation set: Average loss: 0.2917, Accuracy: 9181/10000 (92%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.382237
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.148889
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.270051
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.258075
#
# Train set: Average loss: 0.2589
# Validation set: Average loss: 0.2900, Accuracy: 9170/10000 (92%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.197084
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.296642
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.315191
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.167524
#
# Train set: Average loss: 0.2588
# Validation set: Average loss: 0.2819, Accuracy: 9212/10000 (92%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.244859
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.210236
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.328965
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.315631
#
# Train set: Average loss: 0.2573
# Validation set: Average loss: 0.2920, Accuracy: 9212/10000 (92%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.214606
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.324270
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.644416
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.416674
#
# Train set: Average loss: 0.2562
# Validation set: Average loss: 0.2939, Accuracy: 9150/10000 (92%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.166854
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.329453
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.287745
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.304008
#
# Train set: Average loss: 0.2548
# Validation set: Average loss: 0.2890, Accuracy: 9204/10000 (92%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.159231
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.145126
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.269188
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.288760
#
# Train set: Average loss: 0.2538
# Validation set: Average loss: 0.2868, Accuracy: 9216/10000 (92%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.221157
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.253634
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.160170
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.254072
#
# Train set: Average loss: 0.2537
# Validation set: Average loss: 0.2812, Accuracy: 9207/10000 (92%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.227776
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.272173
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.217482
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.222304
#
# Train set: Average loss: 0.2530
# Validation set: Average loss: 0.2965, Accuracy: 9208/10000 (92%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.234530
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.148490
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.135148
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.214892
#
# Train set: Average loss: 0.2508
# Validation set: Average loss: 0.2889, Accuracy: 9187/10000 (92%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.257684
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.403625
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.155382
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.180465
#
# Train set: Average loss: 0.2517
# Validation set: Average loss: 0.2875, Accuracy: 9221/10000 (92%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.171131
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.299922
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.399779
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.232778
#
# Train set: Average loss: 0.2509
# Validation set: Average loss: 0.2892, Accuracy: 9190/10000 (92%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.187635
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.337627
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.242216
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.203633
#
# Train set: Average loss: 0.2502
# Validation set: Average loss: 0.2945, Accuracy: 9181/10000 (92%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.243300
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.155848
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.246941
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.190889
#
# Train set: Average loss: 0.2496
# Validation set: Average loss: 0.2929, Accuracy: 9163/10000 (92%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.199122
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.342836
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.150649
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.166124
#
# Train set: Average loss: 0.2492
# Validation set: Average loss: 0.2894, Accuracy: 9195/10000 (92%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.188595
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.119370
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.102976
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.373614
#
# Train set: Average loss: 0.2481
# Validation set: Average loss: 0.2950, Accuracy: 9175/10000 (92%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.185760
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.196768
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.173750
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.228146
#
# Train set: Average loss: 0.2481
# Validation set: Average loss: 0.3012, Accuracy: 9171/10000 (92%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.203339
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.218862
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.224428
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.230057
#
# Train set: Average loss: 0.2478
# Validation set: Average loss: 0.2936, Accuracy: 9184/10000 (92%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.105037
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.209651
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.324789
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.166575
#
# Train set: Average loss: 0.2473
# Validation set: Average loss: 0.2940, Accuracy: 9186/10000 (92%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.272464
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.173674
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.252033
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.235821
#
# Train set: Average loss: 0.2468
# Validation set: Average loss: 0.2957, Accuracy: 9211/10000 (92%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.129633
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.186915
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.170607
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.180184
#
# Train set: Average loss: 0.2464
# Validation set: Average loss: 0.2928, Accuracy: 9210/10000 (92%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.300024
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.322026
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.129474
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.225741
#
# Train set: Average loss: 0.2460
# Validation set: Average loss: 0.2896, Accuracy: 9170/10000 (92%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.241603
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.172642
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.367150
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.123743
#
# Train set: Average loss: 0.2448
# Validation set: Average loss: 0.2918, Accuracy: 9221/10000 (92%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.212976
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.386198
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.241784
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.160204
#
# Train set: Average loss: 0.2460
# Validation set: Average loss: 0.3045, Accuracy: 9178/10000 (92%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.292911
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.241050
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.398086
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.215737
#
# Train set: Average loss: 0.2458
# Validation set: Average loss: 0.3003, Accuracy: 9184/10000 (92%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.317885
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.208866
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.354756
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.319856
#
# Train set: Average loss: 0.2446
# Validation set: Average loss: 0.2925, Accuracy: 9173/10000 (92%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.212971
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.244962
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.277702
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.285169
#
# Train set: Average loss: 0.2456
# Validation set: Average loss: 0.2870, Accuracy: 9215/10000 (92%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.368990
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.294311
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.263142
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.303993
#
# Train set: Average loss: 0.2437
# Validation set: Average loss: 0.3005, Accuracy: 9179/10000 (92%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.168703
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.248030
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.117921
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.308892
#
# Train set: Average loss: 0.2436
# Validation set: Average loss: 0.2894, Accuracy: 9227/10000 (92%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.164270
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.171047
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.165871
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.397264
#
# Train set: Average loss: 0.2438
# Validation set: Average loss: 0.2955, Accuracy: 9178/10000 (92%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.133790
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.179572
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.238701
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.176095
#
# Train set: Average loss: 0.2428
# Validation set: Average loss: 0.2996, Accuracy: 9187/10000 (92%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.369627
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.152726
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.209141
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.250377
#
# Train set: Average loss: 0.2423
# Validation set: Average loss: 0.2913, Accuracy: 9217/10000 (92%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.307811
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.348151
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.081600
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.366392
#
# Train set: Average loss: 0.2428
# Validation set: Average loss: 0.2929, Accuracy: 9209/10000 (92%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.198083
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.237801
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.289949
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.308111
#
# Train set: Average loss: 0.2421
# Validation set: Average loss: 0.2926, Accuracy: 9196/10000 (92%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.174000
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.205207
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.158696
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.366550
#
# Train set: Average loss: 0.2420
# Validation set: Average loss: 0.3074, Accuracy: 9145/10000 (91%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.221354
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.312894
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.152532
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.264928
#
# Train set: Average loss: 0.2425
# Validation set: Average loss: 0.2969, Accuracy: 9194/10000 (92%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.168547
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.180018
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.227547
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.235815
#
# Train set: Average loss: 0.2409
# Validation set: Average loss: 0.3115, Accuracy: 9185/10000 (92%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.175238
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.101829
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.205653
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.160779
#
# Train set: Average loss: 0.2420
# Validation set: Average loss: 0.2958, Accuracy: 9175/10000 (92%)
#
# Test set: Average loss: 0.2874, Accuracy: 9184/10000 (92%)

# %% [markdown]
# 2. Now add a hidden layer to the *Perceptron* and evaluate the *Deep* model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Deep().to(device)

optimizer = optim.SGD(model.parameters(),
                      lr=model_args['lr'],
                      momentum=model_args['momentum'])
                      #weight_decay=1.e-3)
#optimizer = optim.Adadelta(model.parameters(), lr=model_args['lr'])

torch.manual_seed(model_args['seed'])
train_loss = []
validation_loss = []
for epoch_number in range(1, model_args['epochs'] + 1):
    train_loss.append(train(model, device, train_loader, optimizer, epoch_number))
    validation_loss.append(test(model, device, validation_loader, 'Validation set'))

test(model, device, test_loader, 'Test set')
plot_loss(train_loss, validation_loss, 'Deep model')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.379134
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 0.244718
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.414567
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.358410
#
# Train set: Average loss: 0.4217
# Validation set: Average loss: 0.2765, Accuracy: 9155/10000 (92%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.226417
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.210981
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.172168
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.134927
#
# Train set: Average loss: 0.2501
# Validation set: Average loss: 0.2302, Accuracy: 9303/10000 (93%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.129700
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.184299
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.264681
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.178343
#
# Train set: Average loss: 0.2045
# Validation set: Average loss: 0.2041, Accuracy: 9399/10000 (94%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.183698
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.122160
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.157821
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.151858
#
# Train set: Average loss: 0.1768
# Validation set: Average loss: 0.1801, Accuracy: 9467/10000 (95%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.071760
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.117161
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.180023
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.306131
#
# Train set: Average loss: 0.1612
# Validation set: Average loss: 0.1835, Accuracy: 9448/10000 (94%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.090596
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 0.126502
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.131158
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.293699
#
# Train set: Average loss: 0.1502
# Validation set: Average loss: 0.1671, Accuracy: 9496/10000 (95%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.146439
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.178844
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.072731
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.180265
#
# Train set: Average loss: 0.1394
# Validation set: Average loss: 0.1694, Accuracy: 9498/10000 (95%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.086529
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.111576
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.124256
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.140271
#
# Train set: Average loss: 0.1329
# Validation set: Average loss: 0.1637, Accuracy: 9521/10000 (95%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.085478
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.272287
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.187096
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.162783
#
# Train set: Average loss: 0.1269
# Validation set: Average loss: 0.1656, Accuracy: 9510/10000 (95%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.041999
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.171788
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.156456
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.153252
#
# Train set: Average loss: 0.1207
# Validation set: Average loss: 0.1651, Accuracy: 9503/10000 (95%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.097306
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.150974
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.125840
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.102857
#
# Train set: Average loss: 0.1172
# Validation set: Average loss: 0.1590, Accuracy: 9543/10000 (95%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.114805
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.077615
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.047336
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.171337
#
# Train set: Average loss: 0.1120
# Validation set: Average loss: 0.1594, Accuracy: 9542/10000 (95%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.060595
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.136349
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.140670
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.081630
#
# Train set: Average loss: 0.1089
# Validation set: Average loss: 0.1626, Accuracy: 9526/10000 (95%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.117699
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.044733
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.128894
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.149484
#
# Train set: Average loss: 0.1059
# Validation set: Average loss: 0.1598, Accuracy: 9516/10000 (95%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.186566
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.064040
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.055018
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.107501
#
# Train set: Average loss: 0.1015
# Validation set: Average loss: 0.1605, Accuracy: 9537/10000 (95%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.157188
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.073605
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.071878
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.098186
#
# Train set: Average loss: 0.0990
# Validation set: Average loss: 0.1598, Accuracy: 9555/10000 (96%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.114010
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.100379
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.130520
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.125721
#
# Train set: Average loss: 0.0966
# Validation set: Average loss: 0.1743, Accuracy: 9497/10000 (95%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.058543
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.089451
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.127210
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.109634
#
# Train set: Average loss: 0.0942
# Validation set: Average loss: 0.1657, Accuracy: 9521/10000 (95%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.056883
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.100762
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.107223
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.087126
#
# Train set: Average loss: 0.0920
# Validation set: Average loss: 0.1557, Accuracy: 9558/10000 (96%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.075706
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.065228
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.085309
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.069976
#
# Train set: Average loss: 0.0903
# Validation set: Average loss: 0.1559, Accuracy: 9560/10000 (96%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.070172
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.134848
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.124507
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.142731
#
# Train set: Average loss: 0.0883
# Validation set: Average loss: 0.1801, Accuracy: 9492/10000 (95%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.116414
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.023657
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.045754
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.072862
#
# Train set: Average loss: 0.0855
# Validation set: Average loss: 0.1603, Accuracy: 9558/10000 (96%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.075637
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.123164
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.044739
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.042056
#
# Train set: Average loss: 0.0834
# Validation set: Average loss: 0.1615, Accuracy: 9548/10000 (95%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.030183
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.118772
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.162029
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.067202
#
# Train set: Average loss: 0.0823
# Validation set: Average loss: 0.1577, Accuracy: 9563/10000 (96%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.065278
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.107553
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.093244
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.059074
#
# Train set: Average loss: 0.0810
# Validation set: Average loss: 0.1615, Accuracy: 9545/10000 (95%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.065037
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.042090
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.120725
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.010683
#
# Train set: Average loss: 0.0782
# Validation set: Average loss: 0.1725, Accuracy: 9526/10000 (95%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.048592
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.143820
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.048408
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.063032
#
# Train set: Average loss: 0.0776
# Validation set: Average loss: 0.1611, Accuracy: 9569/10000 (96%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.155696
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.032129
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.060517
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.128318
#
# Train set: Average loss: 0.0764
# Validation set: Average loss: 0.1693, Accuracy: 9537/10000 (95%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.028710
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.043782
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.028780
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.095690
#
# Train set: Average loss: 0.0748
# Validation set: Average loss: 0.1730, Accuracy: 9553/10000 (96%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.055538
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.099382
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.039398
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.059789
#
# Train set: Average loss: 0.0716
# Validation set: Average loss: 0.1595, Accuracy: 9549/10000 (95%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.030088
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.029253
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.156386
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.039022
#
# Train set: Average loss: 0.0713
# Validation set: Average loss: 0.1783, Accuracy: 9549/10000 (95%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.055295
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.036232
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.018287
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.054622
#
# Train set: Average loss: 0.0695
# Validation set: Average loss: 0.1759, Accuracy: 9554/10000 (96%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.030921
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.020182
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.080212
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.014857
#
# Train set: Average loss: 0.0675
# Validation set: Average loss: 0.1765, Accuracy: 9550/10000 (96%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.066936
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.075729
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.041133
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.055635
#
# Train set: Average loss: 0.0653
# Validation set: Average loss: 0.1713, Accuracy: 9552/10000 (96%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.033196
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.041793
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.183172
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.043196
#
# Train set: Average loss: 0.0660
# Validation set: Average loss: 0.1698, Accuracy: 9548/10000 (95%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.127075
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.110414
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.053429
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.037542
#
# Train set: Average loss: 0.0649
# Validation set: Average loss: 0.1808, Accuracy: 9549/10000 (95%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.063664
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.020288
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.225878
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.107833
#
# Train set: Average loss: 0.0654
# Validation set: Average loss: 0.1738, Accuracy: 9566/10000 (96%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.031419
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.096790
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.089178
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.069271
#
# Train set: Average loss: 0.0616
# Validation set: Average loss: 0.1751, Accuracy: 9556/10000 (96%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.036564
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.071450
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.035271
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.045781
#
# Train set: Average loss: 0.0624
# Validation set: Average loss: 0.1705, Accuracy: 9576/10000 (96%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.041077
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.046646
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.084033
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.022520
#
# Train set: Average loss: 0.0612
# Validation set: Average loss: 0.1725, Accuracy: 9569/10000 (96%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.032627
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.131770
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.026687
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.104614
#
# Train set: Average loss: 0.0588
# Validation set: Average loss: 0.1737, Accuracy: 9574/10000 (96%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.032417
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.034908
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.076581
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.073046
#
# Train set: Average loss: 0.0585
# Validation set: Average loss: 0.1734, Accuracy: 9563/10000 (96%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.016650
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.029543
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.064067
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.020362
#
# Train set: Average loss: 0.0566
# Validation set: Average loss: 0.1768, Accuracy: 9560/10000 (96%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.036223
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.045501
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.042401
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.059898
#
# Train set: Average loss: 0.0568
# Validation set: Average loss: 0.1753, Accuracy: 9567/10000 (96%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.116965
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.069533
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.016746
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.066484
#
# Train set: Average loss: 0.0549
# Validation set: Average loss: 0.1787, Accuracy: 9561/10000 (96%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.054467
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.040609
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.121420
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.133848
#
# Train set: Average loss: 0.0544
# Validation set: Average loss: 0.1769, Accuracy: 9561/10000 (96%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.029874
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.019447
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.050700
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.027854
#
# Train set: Average loss: 0.0536
# Validation set: Average loss: 0.1920, Accuracy: 9542/10000 (95%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.012621
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.094944
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.050802
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.087542
#
# Train set: Average loss: 0.0516
# Validation set: Average loss: 0.1816, Accuracy: 9557/10000 (96%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.019432
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.008265
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.034442
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.068128
#
# Train set: Average loss: 0.0516
# Validation set: Average loss: 0.1941, Accuracy: 9547/10000 (95%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.028734
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.015112
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.068904
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.051814
#
# Train set: Average loss: 0.0520
# Validation set: Average loss: 0.1832, Accuracy: 9548/10000 (95%)
#
# Test set: Average loss: 0.1758, Accuracy: 9575/10000 (96%)

# %% [markdown]
# 3. Compare these results with a deep convolutional network, which is more useful in real-world problems:

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = CNN().to(device)

optimizer = optim.SGD(model.parameters(), lr=model_args['lr'], momentum=model_args['momentum'])
#optimizer = optim.Adadelta(model.parameters(), lr=model_args['lr'])

torch.manual_seed(model_args['seed'])
train_loss = []
validation_loss = []
for epoch_number in range(1, model_args['epochs'] + 1):
    train_loss.append(train(model, device, train_loader, optimizer, epoch_number))
    validation_loss.append(test(model, device, validation_loader, 'Validation set'))

test(model, device, test_loader, 'Test set')
plot_loss(train_loss, validation_loss, 'CNN model')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.313719
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 1.063637
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.824598
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.777870
#
# Train set: Average loss: 1.0578
# Validation set: Average loss: 0.3170, Accuracy: 9051/10000 (91%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.640765
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.769116
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.594840
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.515170
#
# Train set: Average loss: 0.6494
# Validation set: Average loss: 0.2271, Accuracy: 9329/10000 (93%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.776288
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.562186
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.416144
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.625376
#
# Train set: Average loss: 0.5800
# Validation set: Average loss: 0.2124, Accuracy: 9347/10000 (93%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.575958
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.669541
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.545077
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.500885
#
# Train set: Average loss: 0.5394
# Validation set: Average loss: 0.1924, Accuracy: 9438/10000 (94%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.459197
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.515266
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.532957
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.489671
#
# Train set: Average loss: 0.5114
# Validation set: Average loss: 0.1736, Accuracy: 9483/10000 (95%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.418633
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 0.332405
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.358985
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.564616
#
# Train set: Average loss: 0.4873
# Validation set: Average loss: 0.1667, Accuracy: 9496/10000 (95%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.453622
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.531096
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.388424
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.455595
#
# Train set: Average loss: 0.4709
# Validation set: Average loss: 0.1753, Accuracy: 9478/10000 (95%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.401255
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.394369
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.417735
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.495996
#
# Train set: Average loss: 0.4573
# Validation set: Average loss: 0.1669, Accuracy: 9521/10000 (95%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.309637
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.608200
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.440329
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.511969
#
# Train set: Average loss: 0.4472
# Validation set: Average loss: 0.1555, Accuracy: 9538/10000 (95%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.406005
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.405415
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.459697
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.478873
#
# Train set: Average loss: 0.4433
# Validation set: Average loss: 0.1548, Accuracy: 9543/10000 (95%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.338510
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.509080
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.524054
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.506320
#
# Train set: Average loss: 0.4336
# Validation set: Average loss: 0.1564, Accuracy: 9537/10000 (95%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.616841
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.377797
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.457140
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.535276
#
# Train set: Average loss: 0.4282
# Validation set: Average loss: 0.1500, Accuracy: 9524/10000 (95%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.384086
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.454143
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.527744
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.331323
#
# Train set: Average loss: 0.4213
# Validation set: Average loss: 0.1554, Accuracy: 9520/10000 (95%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.470171
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.474355
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.381851
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.292524
#
# Train set: Average loss: 0.4225
# Validation set: Average loss: 0.1486, Accuracy: 9553/10000 (96%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.451829
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.433533
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.481567
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.323891
#
# Train set: Average loss: 0.4222
# Validation set: Average loss: 0.1474, Accuracy: 9556/10000 (96%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.295328
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.459781
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.403253
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.401889
#
# Train set: Average loss: 0.4168
# Validation set: Average loss: 0.1454, Accuracy: 9571/10000 (96%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.290603
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.420099
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.628477
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.612817
#
# Train set: Average loss: 0.4176
# Validation set: Average loss: 0.1427, Accuracy: 9562/10000 (96%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.491394
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.467570
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.260452
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.411862
#
# Train set: Average loss: 0.4169
# Validation set: Average loss: 0.1615, Accuracy: 9500/10000 (95%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.354147
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.345147
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.411682
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.337215
#
# Train set: Average loss: 0.4102
# Validation set: Average loss: 0.1492, Accuracy: 9547/10000 (95%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.369582
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.379023
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.374389
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.450628
#
# Train set: Average loss: 0.4035
# Validation set: Average loss: 0.1463, Accuracy: 9565/10000 (96%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.382293
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.417323
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.442389
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.425197
#
# Train set: Average loss: 0.4043
# Validation set: Average loss: 0.1417, Accuracy: 9563/10000 (96%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.398744
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.340122
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.475108
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.395643
#
# Train set: Average loss: 0.4122
# Validation set: Average loss: 0.1464, Accuracy: 9557/10000 (96%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.290048
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.544191
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.448798
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.388054
#
# Train set: Average loss: 0.4051
# Validation set: Average loss: 0.1446, Accuracy: 9565/10000 (96%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.512317
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.514017
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.397817
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.365566
#
# Train set: Average loss: 0.4061
# Validation set: Average loss: 0.1365, Accuracy: 9585/10000 (96%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.392025
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.455206
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.393730
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.337468
#
# Train set: Average loss: 0.4014
# Validation set: Average loss: 0.1492, Accuracy: 9552/10000 (96%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.337989
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.378640
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.624696
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.255748
#
# Train set: Average loss: 0.4008
# Validation set: Average loss: 0.1414, Accuracy: 9575/10000 (96%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.546167
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.397582
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.531475
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.314025
#
# Train set: Average loss: 0.4009
# Validation set: Average loss: 0.1357, Accuracy: 9578/10000 (96%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.390891
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.278658
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.259790
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.356059
#
# Train set: Average loss: 0.4016
# Validation set: Average loss: 0.1444, Accuracy: 9556/10000 (96%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.298675
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.445975
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.483038
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.364347
#
# Train set: Average loss: 0.3986
# Validation set: Average loss: 0.1380, Accuracy: 9586/10000 (96%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.363595
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.259563
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.365583
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.425966
#
# Train set: Average loss: 0.3940
# Validation set: Average loss: 0.1397, Accuracy: 9578/10000 (96%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.291232
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.440388
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.425439
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.478109
#
# Train set: Average loss: 0.3876
# Validation set: Average loss: 0.1564, Accuracy: 9516/10000 (95%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.353761
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.260850
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.277579
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.333989
#
# Train set: Average loss: 0.3932
# Validation set: Average loss: 0.1350, Accuracy: 9591/10000 (96%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.265566
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.463676
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.382249
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.336719
#
# Train set: Average loss: 0.3935
# Validation set: Average loss: 0.1403, Accuracy: 9560/10000 (96%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.410213
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.283003
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.401276
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.567914
#
# Train set: Average loss: 0.3899
# Validation set: Average loss: 0.1447, Accuracy: 9545/10000 (95%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.402768
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.347275
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.401223
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.477702
#
# Train set: Average loss: 0.3913
# Validation set: Average loss: 0.1403, Accuracy: 9582/10000 (96%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.277604
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.371667
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.325723
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.321796
#
# Train set: Average loss: 0.3912
# Validation set: Average loss: 0.1333, Accuracy: 9604/10000 (96%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.404742
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.381293
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.272299
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.392039
#
# Train set: Average loss: 0.3881
# Validation set: Average loss: 0.1375, Accuracy: 9580/10000 (96%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.321194
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.405073
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.261100
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.443953
#
# Train set: Average loss: 0.3892
# Validation set: Average loss: 0.1420, Accuracy: 9560/10000 (96%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.420953
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.382488
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.328897
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.482348
#
# Train set: Average loss: 0.3863
# Validation set: Average loss: 0.1434, Accuracy: 9559/10000 (96%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.357098
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.359889
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.412908
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.373152
#
# Train set: Average loss: 0.3823
# Validation set: Average loss: 0.1407, Accuracy: 9590/10000 (96%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.481236
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.360804
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.347977
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.481703
#
# Train set: Average loss: 0.3845
# Validation set: Average loss: 0.1385, Accuracy: 9582/10000 (96%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.463986
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.247092
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.353048
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.408323
#
# Train set: Average loss: 0.3846
# Validation set: Average loss: 0.1418, Accuracy: 9571/10000 (96%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.362765
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.372155
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.324081
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.449554
#
# Train set: Average loss: 0.3858
# Validation set: Average loss: 0.1520, Accuracy: 9556/10000 (96%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.363391
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.372071
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.356677
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.374612
#
# Train set: Average loss: 0.3848
# Validation set: Average loss: 0.1463, Accuracy: 9546/10000 (95%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.384564
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.334432
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.398577
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.395505
#
# Train set: Average loss: 0.3868
# Validation set: Average loss: 0.1441, Accuracy: 9585/10000 (96%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.475956
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.377590
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.369996
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.393299
#
# Train set: Average loss: 0.3875
# Validation set: Average loss: 0.1540, Accuracy: 9508/10000 (95%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.327429
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.440378
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.328309
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.341899
#
# Train set: Average loss: 0.3806
# Validation set: Average loss: 0.1415, Accuracy: 9587/10000 (96%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.391148
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.255602
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.451407
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.325870
#
# Train set: Average loss: 0.3818
# Validation set: Average loss: 0.1476, Accuracy: 9563/10000 (96%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.355074
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.283821
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.339724
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.338666
#
# Train set: Average loss: 0.3794
# Validation set: Average loss: 0.1387, Accuracy: 9608/10000 (96%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.436758
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.374083
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.507819
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.364465
#
# Train set: Average loss: 0.3839
# Validation set: Average loss: 0.1364, Accuracy: 9579/10000 (96%)
#
# Test set: Average loss: 0.1117, Accuracy: 9641/10000 (96%)

# %% [markdown]
# ## Summary
# * *Deep* and *CNN* models with accuracies of 96% and 97% (evaluated on the test subset) perform much better than single-layer *Perceptron* with 92%;
# * The two smallest (and simplest) models appear to be overfitted. To deal with this we need to apply some regularization.
# * Validation subset is evaluated during the training (as opposed to test set, infered *after* the training) in order to tune the model hiperparameters (that describe e.g. the network structure, or training details).
# * A moment to stop trainning is a kind of hipermarameter -- by applying *early stopping* we can avoid overfitting.

# %% [markdown]
# ## Tasks to do
# * apply some regularization technique to *Deep* model in order to avoid overfitting (start with nonzero *weight_decay* in optimizer)
# * try to figure out why the validation loss for *CNN* model turns to be *lower* than the train loss (hint: turn off regularization),
# * **tune one of these models to get the *Test Set Accuracy* > 99%**,
# * plot the *confusion matrix* among all of the classes---which of digits are mostly confused with each other?
# >How to build the confusion matrix?
# > * for example 1st row represents images with "0" digit (*ground truth*), while 1st colum images for which the model *predicts* "0",
# > * this way element _11 is equal to number of images with "0" corectly clasified as "0" (true positives), while _15 means number of images with "0" wrongly calssified as "4", and so on.
