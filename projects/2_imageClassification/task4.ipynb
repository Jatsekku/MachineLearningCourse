# %% [markdown]
# # Classification of handwritten digits using various neural network models with PyTorch
# * Multinomial classification task of images of handwritten digits (10 classes).
# * The database has a training set of 60k examples, and a test set of 10k examples, each image is of 28x28 pixels size.
# * The MNIST ("Modified National Institute of Standards and Technology") is the “hello world” dataset for computer vision. Since its release in 1999, this classic dataset of handwritten images has served as the basis for benchmarking classification algorithms.

# %% [markdown]
# ## Model setup

# %% [markdown]
# Before we start we need to load libraries and setup the model parameters

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from sklearn.metrics import confusion_matrix
import seaborn as sns

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 14})

model_args = {}
# random seed
model_args['seed'] = 123
# we will use batch size of 128 in Stochastic Gradient Descent (SGD) optimization of the network
model_args['batch_size'] = 128
# learning rate is how fast it will descend
model_args['lr'] = .05
# SGD momentum (default: .5) momentum is a moving average of gradients (it helps to keep direction)
model_args['momentum'] = .5
# the number of epochs is the number of times you go through the full dataset
model_args['epochs'] = 50
# logging frequency
model_args['log_interval'] = 100

# %%
# load the MINST dataset via torchvision
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.1307,), (0.3081,))])
mnist_train = datasets.MNIST('../data', train=True, download=True, transform=transform)
# we divide this data into training and validation subsets
train_subset, validation_subset = torch.utils.data.random_split(mnist_train, [50000, 10000])
test_subset = datasets.MNIST('../data', train=False, download=True, transform=transform)

# %% [markdown]
# Second method: directly download tar.gz archive

# %%
# define dataloaders
loader_kwargs = {'batch_size': model_args['batch_size'],
                 'num_workers': 2,
                 'pin_memory': True,
                 'shuffle': True}
train_loader = torch.utils.data.DataLoader(train_subset, **loader_kwargs)
validation_loader = torch.utils.data.DataLoader(validation_subset, **loader_kwargs)
test_loader = torch.utils.data.DataLoader(test_subset, **loader_kwargs)

# %% [markdown]
# Plot sample images

# %%
print(len(train_subset))
print(len(validation_subset))
print(len(test_subset)) # we have data already divided into train & validation & test subsets
print(len(train_loader)) # no of train batches
example_number = 123
print(train_subset[example_number][0][0].shape) # single item shape

fig, axs = plt.subplots(5, 5, figsize=(7,7), tight_layout=True)
for i in range(5):
    for j in range(5):
        axs[i,j].imshow(train_subset[example_number+i*5+j][0].reshape(28,28), cmap='gray')
        axs[i,j].set_title(train_subset[example_number+i*5+j][1])
# Out:
# 50000
# 10000
# 10000
# 391
# torch.Size([28, 28])

# %% [markdown]
# Let's now construct the NN models:
# - we start with siplest single layer **perceptron** with *softmax* activation,
# - then test **deep** network with some (fully-connected) *hidden* layers,
# - and finally setup deep **convolutional neural network**.

# %%
class Perceptron(nn.Module):
    # this defines the structure of the Perceptron model
    def __init__(self):
        super(Perceptron, self).__init__()
        # fully connected layer
        self.fc = nn.Linear(28*28, 10)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc(x)
        return F.log_softmax(x, dim=1) # note that dim=0 is the number of samples in batch

class Deep(nn.Module):
    # this defines the structure of the Perceptron model
    def __init__(self):
        super(Deep, self).__init__()
        # fully connected layers
        self.fc1 = nn.Linear(28*28, 20)
        self.fc2 = nn.Linear(20, 10)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = F.relu(x)
        # hidden layer
        x = self.fc2(x)
        return F.log_softmax(x, dim=1) # note that dim=0 is the number of samples in batch

class CNN(nn.Module):
    # this defines the structure of the CNN model
    def __init__(self):
        super(CNN, self).__init__()
        # convolutional layer with 2 kernels of size 5x5
        self.conv1 = nn.Conv2d(1, 2, kernel_size=5)
        # 4 kernels of size 5x5
        self.conv2 = nn.Conv2d(2, 4, kernel_size=5)
        # 2D dropout
        self.conv2_drop = nn.Dropout2d()
        # fully connected layers
        self.fc1 = nn.Linear(64, 20)
        self.fc2 = nn.Linear(20, 10)

    def forward(self, x):
        # 1st layers group
        x = self.conv1(x) # resulting in 2 feature maps each of size 24x24
        x = F.max_pool2d(x, 2) # downsizing each map to 12x12
        x = F.relu(x) # standard (in CNNs) ReLU activation
        # 2nd group
        x = self.conv2(x) # resulting in 4 feature maps each of size 8x8
        # x = self.conv2_drop(x)
        x = F.max_pool2d(x, 2) # downsizing each map to 4x4
        x = F.relu(x)
        # fully connected layers
        x = x.view(-1, 64) # 4 maps of 4x4 size gives 64 numbers
        x = self.fc1(x) # 64 -> 20
        x = F.relu(x)
        x = F.dropout(x, training=self.training) # dropout is a type of regularization
        x = self.fc2(x) # 20 -> 10
        # softmax (multinomial classification) gives probabilities of each class
        return F.log_softmax(x, dim=1) # note that dim=0 is the number of samples in batch

# %% [markdown]
# And define training, testing, and plotting utils:

# %%
def train(model, device, train_loader, optimizer, epoch_number):
    model.train()
    train_loss = 0.
    # get subsequent batches over the data in a given epoch
    for batch_idx, (data, target) in enumerate(train_loader):
        # send data tensors to GPU (or CPU)
        data, target = data.to(device), target.to(device)
        # this will zero out the gradients for this batch
        optimizer.zero_grad()
        # this will execute the forward() function
        output = model(data)
        # calculate the negative-log-likelihood loss
        loss = F.nll_loss(output, target, reduction='mean')
        # backpropagate the loss
        loss.backward()
        # update the model weights (with assumed learning rate)
        optimizer.step()
        if batch_idx % model_args['log_interval'] == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch_number, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))
        train_loss += loss.item()
    train_loss /= len(train_loader)
    print('\nTrain set: Average loss: {:.4f}'.format(train_loss))
    return train_loss

def test(model, device, test_loader, message):
    model.eval()
    test_loss = 0.
    correct = 0
    # this is just inference, we don't need to calculate gradients
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            # calculate and sum up batch loss
            test_loss += F.nll_loss(output, target, reduction='mean')
            # get the index of class with the max log-probability
            prediction = output.argmax(dim=1)
            # item() returns value of the given tensor
            correct += prediction.eq(target).sum().item()
    test_loss /= len(test_loader)
    print('{}: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        message, test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss.cpu()

def plot_confussion_matrix(model, device, test_loader):
    model.eval()
    all_preds = []
    all_targets = []

    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            preds = output.argmax(dim=1)
            all_preds.append(preds.cpu())
            all_targets.append(target.cpu())

    all_preds = torch.cat(all_preds)
    all_targets = torch.cat(all_targets)

    # compute confusion matrix
    cm = confusion_matrix(all_targets, all_preds)

    # plot
    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title("Confussion Matrix")
    plt.show()
            
            
    
def plot_loss(train_loss, validation_loss, title):
    plt.grid(True)
    plt.xlabel("subsequent epochs")
    plt.ylabel('average loss')
    plt.plot(range(1, len(train_loss)+1), train_loss, 'o-', label='training')
    plt.plot(range(1, len(validation_loss)+1), validation_loss, 'o-', label='validation')
    plt.legend()
    plt.title(title)
    plt.show()

# %% [markdown]
# ## Experiments

# %% [markdown]
# 1. At first let's test the single-layer *Perceptron* model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Perceptron().to(device)

optimizer = optim.SGD(model.parameters(), lr=model_args['lr'], momentum=model_args['momentum'])
#optimizer = optim.Adadelta(model.parameters(), lr=model_args['lr'])

torch.manual_seed(model_args['seed'])
train_loss = []
validation_loss = []
for epoch_number in range(1, model_args['epochs'] + 1):
    train_loss.append(train(model, device, train_loader, optimizer, epoch_number))
    validation_loss.append(test(model, device, validation_loader, 'Validation set'))

test(model, device, test_loader, 'Test set')
plot_loss(train_loss, validation_loss, 'Perceptron model')
plot_confussion_matrix(model, device, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.360998
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 0.384705
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.238845
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.290775
#
# Train set: Average loss: 0.3748
# Validation set: Average loss: 0.3374, Accuracy: 9030/10000 (90%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.307345
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.263704
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.202709
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.324102
#
# Train set: Average loss: 0.3014
# Validation set: Average loss: 0.3096, Accuracy: 9131/10000 (91%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.300606
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.274724
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.151395
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.280501
#
# Train set: Average loss: 0.2894
# Validation set: Average loss: 0.3068, Accuracy: 9139/10000 (91%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.415251
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.522645
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.333772
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.134326
#
# Train set: Average loss: 0.2818
# Validation set: Average loss: 0.2990, Accuracy: 9133/10000 (91%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.201064
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.370055
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.139089
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.284605
#
# Train set: Average loss: 0.2768
# Validation set: Average loss: 0.3061, Accuracy: 9117/10000 (91%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.360981
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 0.309734
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.395744
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.252972
#
# Train set: Average loss: 0.2725
# Validation set: Average loss: 0.2980, Accuracy: 9125/10000 (91%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.189483
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.193985
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.535774
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.223080
#
# Train set: Average loss: 0.2692
# Validation set: Average loss: 0.2963, Accuracy: 9157/10000 (92%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.285181
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.338562
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.259288
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.313893
#
# Train set: Average loss: 0.2665
# Validation set: Average loss: 0.2984, Accuracy: 9161/10000 (92%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.187041
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.192059
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.236825
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.306510
#
# Train set: Average loss: 0.2643
# Validation set: Average loss: 0.2916, Accuracy: 9155/10000 (92%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.322540
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.339263
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.237305
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.324021
#
# Train set: Average loss: 0.2622
# Validation set: Average loss: 0.2937, Accuracy: 9171/10000 (92%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.175457
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.543508
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.191732
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.230919
#
# Train set: Average loss: 0.2610
# Validation set: Average loss: 0.2982, Accuracy: 9149/10000 (91%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.227412
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.340242
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.236419
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.297798
#
# Train set: Average loss: 0.2595
# Validation set: Average loss: 0.2894, Accuracy: 9184/10000 (92%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.152448
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.287637
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.315225
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.193551
#
# Train set: Average loss: 0.2577
# Validation set: Average loss: 0.2968, Accuracy: 9145/10000 (91%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.190433
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.159271
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.196099
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.269543
#
# Train set: Average loss: 0.2562
# Validation set: Average loss: 0.3092, Accuracy: 9135/10000 (91%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.283689
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.309825
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.312523
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.251123
#
# Train set: Average loss: 0.2564
# Validation set: Average loss: 0.3088, Accuracy: 9157/10000 (92%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.236673
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.243128
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.291230
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.175135
#
# Train set: Average loss: 0.2544
# Validation set: Average loss: 0.2991, Accuracy: 9184/10000 (92%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.156672
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.174275
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.247619
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.213741
#
# Train set: Average loss: 0.2537
# Validation set: Average loss: 0.2936, Accuracy: 9167/10000 (92%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.283489
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.206907
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.169202
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.291014
#
# Train set: Average loss: 0.2534
# Validation set: Average loss: 0.2987, Accuracy: 9149/10000 (91%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.287201
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.260217
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.224250
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.328572
#
# Train set: Average loss: 0.2514
# Validation set: Average loss: 0.3000, Accuracy: 9152/10000 (92%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.254956
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.370066
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.234228
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.175425
#
# Train set: Average loss: 0.2507
# Validation set: Average loss: 0.3103, Accuracy: 9142/10000 (91%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.316408
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.162332
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.267030
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.216690
#
# Train set: Average loss: 0.2501
# Validation set: Average loss: 0.2998, Accuracy: 9163/10000 (92%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.266252
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.308363
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.254342
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.143840
#
# Train set: Average loss: 0.2492
# Validation set: Average loss: 0.3004, Accuracy: 9143/10000 (91%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.231391
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.284793
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.257381
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.304296
#
# Train set: Average loss: 0.2499
# Validation set: Average loss: 0.2960, Accuracy: 9168/10000 (92%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.160837
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.142762
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.175379
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.279406
#
# Train set: Average loss: 0.2483
# Validation set: Average loss: 0.3029, Accuracy: 9158/10000 (92%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.317737
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.108693
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.174782
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.231684
#
# Train set: Average loss: 0.2477
# Validation set: Average loss: 0.3179, Accuracy: 9099/10000 (91%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.189148
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.239790
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.186426
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.193662
#
# Train set: Average loss: 0.2468
# Validation set: Average loss: 0.3044, Accuracy: 9137/10000 (91%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.362456
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.234814
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.199863
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.285767
#
# Train set: Average loss: 0.2468
# Validation set: Average loss: 0.3092, Accuracy: 9136/10000 (91%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.288730
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.254748
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.341494
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.230191
#
# Train set: Average loss: 0.2456
# Validation set: Average loss: 0.3159, Accuracy: 9147/10000 (91%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.227136
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.157203
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.382316
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.183157
#
# Train set: Average loss: 0.2467
# Validation set: Average loss: 0.3174, Accuracy: 9146/10000 (91%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.263022
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.184179
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.235497
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.177346
#
# Train set: Average loss: 0.2455
# Validation set: Average loss: 0.3059, Accuracy: 9161/10000 (92%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.192085
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.214147
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.286024
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.241018
#
# Train set: Average loss: 0.2451
# Validation set: Average loss: 0.3051, Accuracy: 9161/10000 (92%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.178386
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.234100
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.149517
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.299624
#
# Train set: Average loss: 0.2441
# Validation set: Average loss: 0.3119, Accuracy: 9154/10000 (92%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.118424
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.260207
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.252010
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.195892
#
# Train set: Average loss: 0.2440
# Validation set: Average loss: 0.3021, Accuracy: 9176/10000 (92%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.342177
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.349441
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.319358
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.214267
#
# Train set: Average loss: 0.2431
# Validation set: Average loss: 0.3058, Accuracy: 9165/10000 (92%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.132678
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.323237
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.291748
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.217041
#
# Train set: Average loss: 0.2424
# Validation set: Average loss: 0.3019, Accuracy: 9169/10000 (92%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.120658
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.132575
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.220548
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.165522
#
# Train set: Average loss: 0.2431
# Validation set: Average loss: 0.3051, Accuracy: 9148/10000 (91%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.253359
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.140754
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.129218
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.303450
#
# Train set: Average loss: 0.2430
# Validation set: Average loss: 0.3161, Accuracy: 9119/10000 (91%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.375452
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.184883
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.344994
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.217526
#
# Train set: Average loss: 0.2420
# Validation set: Average loss: 0.3042, Accuracy: 9150/10000 (92%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.279474
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.123463
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.122304
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.221003
#
# Train set: Average loss: 0.2418
# Validation set: Average loss: 0.3134, Accuracy: 9142/10000 (91%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.229332
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.207912
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.204342
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.312241
#
# Train set: Average loss: 0.2414
# Validation set: Average loss: 0.3081, Accuracy: 9145/10000 (91%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.199793
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.214667
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.398310
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.251308
#
# Train set: Average loss: 0.2408
# Validation set: Average loss: 0.3072, Accuracy: 9164/10000 (92%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.313937
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.120206
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.645604
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.394001
#
# Train set: Average loss: 0.2411
# Validation set: Average loss: 0.3127, Accuracy: 9147/10000 (91%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.352697
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.249129
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.103707
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.224837
#
# Train set: Average loss: 0.2407
# Validation set: Average loss: 0.3060, Accuracy: 9171/10000 (92%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.197208
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.096397
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.298430
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.230526
#
# Train set: Average loss: 0.2403
# Validation set: Average loss: 0.3127, Accuracy: 9159/10000 (92%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.087791
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.411868
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.146503
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.231708
#
# Train set: Average loss: 0.2398
# Validation set: Average loss: 0.3080, Accuracy: 9164/10000 (92%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.201372
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.223539
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.261270
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.211560
#
# Train set: Average loss: 0.2390
# Validation set: Average loss: 0.3084, Accuracy: 9137/10000 (91%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.177703
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.273342
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.168590
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.195280
#
# Train set: Average loss: 0.2392
# Validation set: Average loss: 0.3065, Accuracy: 9145/10000 (91%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.310253
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.176027
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.276004
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.325995
#
# Train set: Average loss: 0.2391
# Validation set: Average loss: 0.3202, Accuracy: 9146/10000 (91%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.212572
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.304209
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.293134
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.373502
#
# Train set: Average loss: 0.2378
# Validation set: Average loss: 0.3058, Accuracy: 9159/10000 (92%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.139582
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.142349
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.163274
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.220532
#
# Train set: Average loss: 0.2381
# Validation set: Average loss: 0.3088, Accuracy: 9154/10000 (92%)
#
# Test set: Average loss: 0.2864, Accuracy: 9230/10000 (92%)

# %% [markdown]
# 2. Now add a hidden layer to the *Perceptron* and evaluate the *Deep* model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Deep().to(device)

optimizer = optim.SGD(model.parameters(),
                      lr=model_args['lr'],
                      momentum=model_args['momentum'])
                      #weight_decay=1.e-3)
#optimizer = optim.Adadelta(model.parameters(), lr=model_args['lr'])

torch.manual_seed(model_args['seed'])
train_loss = []
validation_loss = []
for epoch_number in range(1, model_args['epochs'] + 1):
    train_loss.append(train(model, device, train_loader, optimizer, epoch_number))
    validation_loss.append(test(model, device, validation_loader, 'Validation set'))

test(model, device, test_loader, 'Test set')
plot_loss(train_loss, validation_loss, 'Deep model')
plot_confussion_matrix(model, device, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.367748
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 0.395163
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.224229
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.289507
#
# Train set: Average loss: 0.4154
# Validation set: Average loss: 0.2922, Accuracy: 9174/10000 (92%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.209406
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.223782
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.148032
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.226203
#
# Train set: Average loss: 0.2310
# Validation set: Average loss: 0.2190, Accuracy: 9369/10000 (94%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.208320
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.130120
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.094863
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.191143
#
# Train set: Average loss: 0.1873
# Validation set: Average loss: 0.1948, Accuracy: 9435/10000 (94%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.324403
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.302536
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.194657
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.064208
#
# Train set: Average loss: 0.1655
# Validation set: Average loss: 0.1847, Accuracy: 9449/10000 (94%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.127180
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.198421
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.054000
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.127837
#
# Train set: Average loss: 0.1516
# Validation set: Average loss: 0.1886, Accuracy: 9455/10000 (95%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.186316
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 0.157524
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.201214
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.109130
#
# Train set: Average loss: 0.1406
# Validation set: Average loss: 0.1688, Accuracy: 9486/10000 (95%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.104201
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.122893
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.214108
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.082648
#
# Train set: Average loss: 0.1336
# Validation set: Average loss: 0.1658, Accuracy: 9508/10000 (95%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.090564
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.176932
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.068439
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.169957
#
# Train set: Average loss: 0.1266
# Validation set: Average loss: 0.1606, Accuracy: 9535/10000 (95%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.085265
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.073896
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.100694
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.160560
#
# Train set: Average loss: 0.1207
# Validation set: Average loss: 0.1571, Accuracy: 9547/10000 (95%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.124563
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.151613
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.154301
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.181517
#
# Train set: Average loss: 0.1165
# Validation set: Average loss: 0.1634, Accuracy: 9504/10000 (95%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.075015
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.328787
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.090289
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.063449
#
# Train set: Average loss: 0.1130
# Validation set: Average loss: 0.1642, Accuracy: 9517/10000 (95%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.067783
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.121880
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.127646
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.175166
#
# Train set: Average loss: 0.1092
# Validation set: Average loss: 0.1571, Accuracy: 9551/10000 (96%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.040263
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.068823
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.140460
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.135111
#
# Train set: Average loss: 0.1052
# Validation set: Average loss: 0.1551, Accuracy: 9534/10000 (95%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.031680
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.067563
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.074904
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.173971
#
# Train set: Average loss: 0.1025
# Validation set: Average loss: 0.1568, Accuracy: 9541/10000 (95%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.135849
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.059665
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.100138
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.060643
#
# Train set: Average loss: 0.1001
# Validation set: Average loss: 0.1622, Accuracy: 9530/10000 (95%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.107436
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.035794
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.139729
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.047208
#
# Train set: Average loss: 0.0970
# Validation set: Average loss: 0.1660, Accuracy: 9527/10000 (95%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.045704
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.043033
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.041532
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.070842
#
# Train set: Average loss: 0.0954
# Validation set: Average loss: 0.1633, Accuracy: 9536/10000 (95%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.103709
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.057402
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.060940
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.086916
#
# Train set: Average loss: 0.0932
# Validation set: Average loss: 0.1684, Accuracy: 9523/10000 (95%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.101162
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.038727
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.052670
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.168052
#
# Train set: Average loss: 0.0899
# Validation set: Average loss: 0.1722, Accuracy: 9518/10000 (95%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.091811
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.092203
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.107124
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.114488
#
# Train set: Average loss: 0.0889
# Validation set: Average loss: 0.1752, Accuracy: 9521/10000 (95%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.103267
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.060000
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.054106
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.088561
#
# Train set: Average loss: 0.0872
# Validation set: Average loss: 0.1676, Accuracy: 9536/10000 (95%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.047134
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.129029
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.066554
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.074023
#
# Train set: Average loss: 0.0845
# Validation set: Average loss: 0.1764, Accuracy: 9504/10000 (95%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.023173
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.141247
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.081953
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.050663
#
# Train set: Average loss: 0.0843
# Validation set: Average loss: 0.1682, Accuracy: 9532/10000 (95%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.056024
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.062668
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.082634
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.136488
#
# Train set: Average loss: 0.0816
# Validation set: Average loss: 0.1760, Accuracy: 9522/10000 (95%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.199017
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.016741
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.058713
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.067016
#
# Train set: Average loss: 0.0798
# Validation set: Average loss: 0.1889, Accuracy: 9506/10000 (95%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.107889
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.076725
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.033273
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.063850
#
# Train set: Average loss: 0.0778
# Validation set: Average loss: 0.1720, Accuracy: 9537/10000 (95%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.104107
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.053579
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.055823
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.122084
#
# Train set: Average loss: 0.0776
# Validation set: Average loss: 0.1780, Accuracy: 9522/10000 (95%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.099291
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.038573
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.046365
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.102141
#
# Train set: Average loss: 0.0757
# Validation set: Average loss: 0.1784, Accuracy: 9530/10000 (95%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.032707
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.040064
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.086058
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.103793
#
# Train set: Average loss: 0.0741
# Validation set: Average loss: 0.1878, Accuracy: 9493/10000 (95%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.056896
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.100706
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.092023
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.049675
#
# Train set: Average loss: 0.0747
# Validation set: Average loss: 0.1831, Accuracy: 9521/10000 (95%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.042607
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.031813
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.051009
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.071434
#
# Train set: Average loss: 0.0725
# Validation set: Average loss: 0.1821, Accuracy: 9514/10000 (95%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.071428
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.046344
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.023811
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.098992
#
# Train set: Average loss: 0.0703
# Validation set: Average loss: 0.1874, Accuracy: 9517/10000 (95%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.030099
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.060900
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.109058
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.061184
#
# Train set: Average loss: 0.0690
# Validation set: Average loss: 0.1915, Accuracy: 9510/10000 (95%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.074118
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.069406
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.184038
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.029491
#
# Train set: Average loss: 0.0684
# Validation set: Average loss: 0.1847, Accuracy: 9533/10000 (95%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.063062
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.063043
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.123067
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.053285
#
# Train set: Average loss: 0.0672
# Validation set: Average loss: 0.1870, Accuracy: 9520/10000 (95%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.021719
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.027027
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.050216
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.067255
#
# Train set: Average loss: 0.0670
# Validation set: Average loss: 0.1886, Accuracy: 9504/10000 (95%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.113100
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.018817
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.020158
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.091073
#
# Train set: Average loss: 0.0658
# Validation set: Average loss: 0.1903, Accuracy: 9524/10000 (95%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.020582
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.027950
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.065375
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.032733
#
# Train set: Average loss: 0.0649
# Validation set: Average loss: 0.1928, Accuracy: 9521/10000 (95%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.077828
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.076358
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.062369
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.069399
#
# Train set: Average loss: 0.0635
# Validation set: Average loss: 0.1922, Accuracy: 9524/10000 (95%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.041700
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.031861
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.035032
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.045371
#
# Train set: Average loss: 0.0618
# Validation set: Average loss: 0.1903, Accuracy: 9513/10000 (95%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.056426
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.055056
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.049435
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.081491
#
# Train set: Average loss: 0.0616
# Validation set: Average loss: 0.2030, Accuracy: 9492/10000 (95%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.156908
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.039856
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.231838
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.128656
#
# Train set: Average loss: 0.0616
# Validation set: Average loss: 0.1971, Accuracy: 9532/10000 (95%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.059000
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.036001
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.022652
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.063829
#
# Train set: Average loss: 0.0602
# Validation set: Average loss: 0.1960, Accuracy: 9510/10000 (95%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.041147
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.006112
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.038474
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.073803
#
# Train set: Average loss: 0.0597
# Validation set: Average loss: 0.1996, Accuracy: 9509/10000 (95%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.039987
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.180706
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.046740
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.036585
#
# Train set: Average loss: 0.0584
# Validation set: Average loss: 0.2343, Accuracy: 9453/10000 (95%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.108926
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.035519
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.054844
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.152472
#
# Train set: Average loss: 0.0583
# Validation set: Average loss: 0.2092, Accuracy: 9508/10000 (95%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.046735
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.067573
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.034924
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.044282
#
# Train set: Average loss: 0.0576
# Validation set: Average loss: 0.2057, Accuracy: 9506/10000 (95%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.048490
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.034864
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.052098
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.084026
#
# Train set: Average loss: 0.0562
# Validation set: Average loss: 0.2090, Accuracy: 9504/10000 (95%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.022396
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.063290
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.049301
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.101351
#
# Train set: Average loss: 0.0547
# Validation set: Average loss: 0.2085, Accuracy: 9516/10000 (95%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.015909
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.031301
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.037947
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.056847
#
# Train set: Average loss: 0.0549
# Validation set: Average loss: 0.2112, Accuracy: 9506/10000 (95%)
#
# Test set: Average loss: 0.1884, Accuracy: 9552/10000 (96%)

# %% [markdown]
# 3. Compare these results with a deep convolutional network, which is more useful in real-world problems:

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = CNN().to(device)

optimizer = optim.SGD(model.parameters(), lr=model_args['lr'], momentum=model_args['momentum'])
#optimizer = optim.Adadelta(model.parameters(), lr=model_args['lr'])

torch.manual_seed(model_args['seed'])
train_loss = []
validation_loss = []
for epoch_number in range(1, model_args['epochs'] + 1):
    train_loss.append(train(model, device, train_loader, optimizer, epoch_number))
    validation_loss.append(test(model, device, validation_loader, 'Validation set'))

test(model, device, test_loader, 'Test set')
plot_loss(train_loss, validation_loss, 'CNN model')
plot_confussion_matrix(model, device, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.318409
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 1.117652
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 0.978891
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 0.914777
#
# Train set: Average loss: 1.1645
# Validation set: Average loss: 0.4080, Accuracy: 8807/10000 (88%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.784820
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 0.822722
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 0.716250
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.654743
#
# Train set: Average loss: 0.7233
# Validation set: Average loss: 0.2759, Accuracy: 9140/10000 (91%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.632700
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.711922
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.476687
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.511784
#
# Train set: Average loss: 0.6284
# Validation set: Average loss: 0.2278, Accuracy: 9330/10000 (93%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.781023
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.578835
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.728654
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.405409
#
# Train set: Average loss: 0.5673
# Validation set: Average loss: 0.2129, Accuracy: 9341/10000 (93%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.467919
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.522579
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.579865
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.548572
#
# Train set: Average loss: 0.5301
# Validation set: Average loss: 0.2221, Accuracy: 9311/10000 (93%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.450074
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 0.439559
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.554827
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.590636
#
# Train set: Average loss: 0.5136
# Validation set: Average loss: 0.1906, Accuracy: 9423/10000 (94%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.526153
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.509792
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.517155
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.533694
#
# Train set: Average loss: 0.5004
# Validation set: Average loss: 0.1794, Accuracy: 9440/10000 (94%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.442952
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.631380
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.479173
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.551419
#
# Train set: Average loss: 0.4836
# Validation set: Average loss: 0.1829, Accuracy: 9482/10000 (95%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.417165
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.478764
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.547707
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.431189
#
# Train set: Average loss: 0.4782
# Validation set: Average loss: 0.1837, Accuracy: 9460/10000 (95%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.550147
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.392847
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.401125
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.528407
#
# Train set: Average loss: 0.4718
# Validation set: Average loss: 0.1744, Accuracy: 9493/10000 (95%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.405177
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.585331
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.444436
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.454947
#
# Train set: Average loss: 0.4683
# Validation set: Average loss: 0.1740, Accuracy: 9494/10000 (95%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.460934
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.387674
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.533345
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.455536
#
# Train set: Average loss: 0.4518
# Validation set: Average loss: 0.1603, Accuracy: 9532/10000 (95%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.445457
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.371038
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.375960
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.364553
#
# Train set: Average loss: 0.4473
# Validation set: Average loss: 0.1739, Accuracy: 9463/10000 (95%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.447498
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.352884
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.426990
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.489748
#
# Train set: Average loss: 0.4558
# Validation set: Average loss: 0.1605, Accuracy: 9534/10000 (95%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.545373
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.358775
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.430950
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.493969
#
# Train set: Average loss: 0.4429
# Validation set: Average loss: 0.1625, Accuracy: 9512/10000 (95%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.543916
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.356965
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.475144
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.434318
#
# Train set: Average loss: 0.4413
# Validation set: Average loss: 0.1740, Accuracy: 9483/10000 (95%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.600551
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.305442
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.488142
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.351695
#
# Train set: Average loss: 0.4306
# Validation set: Average loss: 0.1574, Accuracy: 9537/10000 (95%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.450648
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.406264
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.399098
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.347106
#
# Train set: Average loss: 0.4339
# Validation set: Average loss: 0.1609, Accuracy: 9485/10000 (95%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.380416
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.439945
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.425158
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.343813
#
# Train set: Average loss: 0.4298
# Validation set: Average loss: 0.1622, Accuracy: 9499/10000 (95%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.560145
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.471675
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.409469
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.556027
#
# Train set: Average loss: 0.4309
# Validation set: Average loss: 0.1555, Accuracy: 9521/10000 (95%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.481336
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.436349
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.426333
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.445061
#
# Train set: Average loss: 0.4260
# Validation set: Average loss: 0.1534, Accuracy: 9542/10000 (95%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.427086
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.397131
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.427181
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.399025
#
# Train set: Average loss: 0.4279
# Validation set: Average loss: 0.1500, Accuracy: 9541/10000 (95%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.519329
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.528158
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.519406
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.457038
#
# Train set: Average loss: 0.4285
# Validation set: Average loss: 0.1627, Accuracy: 9511/10000 (95%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.379267
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.392651
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.428468
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.359294
#
# Train set: Average loss: 0.4196
# Validation set: Average loss: 0.1696, Accuracy: 9519/10000 (95%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.553990
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.340594
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.300359
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.486133
#
# Train set: Average loss: 0.4176
# Validation set: Average loss: 0.1527, Accuracy: 9545/10000 (95%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.259958
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.411290
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.291365
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.436672
#
# Train set: Average loss: 0.4218
# Validation set: Average loss: 0.1592, Accuracy: 9520/10000 (95%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.387327
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.379680
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.209786
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.514104
#
# Train set: Average loss: 0.4192
# Validation set: Average loss: 0.1644, Accuracy: 9521/10000 (95%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.434885
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.450588
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.455894
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.253437
#
# Train set: Average loss: 0.4119
# Validation set: Average loss: 0.1556, Accuracy: 9539/10000 (95%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.239188
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.241837
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.388881
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.286416
#
# Train set: Average loss: 0.4153
# Validation set: Average loss: 0.1526, Accuracy: 9541/10000 (95%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.445084
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.269928
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.449082
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.365469
#
# Train set: Average loss: 0.4154
# Validation set: Average loss: 0.1749, Accuracy: 9447/10000 (94%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.420931
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.369827
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.412977
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.436553
#
# Train set: Average loss: 0.4151
# Validation set: Average loss: 0.1509, Accuracy: 9547/10000 (95%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.330115
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.403659
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.310713
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.364401
#
# Train set: Average loss: 0.4089
# Validation set: Average loss: 0.1479, Accuracy: 9556/10000 (96%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.426078
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.495609
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.548362
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.307883
#
# Train set: Average loss: 0.4191
# Validation set: Average loss: 0.1534, Accuracy: 9551/10000 (96%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.491133
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.375598
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.365577
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.394861
#
# Train set: Average loss: 0.4125
# Validation set: Average loss: 0.1531, Accuracy: 9540/10000 (95%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.395438
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.495599
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.432094
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.363690
#
# Train set: Average loss: 0.4129
# Validation set: Average loss: 0.1577, Accuracy: 9567/10000 (96%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.512213
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.393494
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.376434
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.379400
#
# Train set: Average loss: 0.4073
# Validation set: Average loss: 0.1494, Accuracy: 9571/10000 (96%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.385503
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.380911
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.345973
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.445008
#
# Train set: Average loss: 0.4026
# Validation set: Average loss: 0.1472, Accuracy: 9566/10000 (96%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.425941
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.344305
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.351779
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.388159
#
# Train set: Average loss: 0.4053
# Validation set: Average loss: 0.1434, Accuracy: 9562/10000 (96%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.524172
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.320143
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.361981
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.417618
#
# Train set: Average loss: 0.4024
# Validation set: Average loss: 0.1515, Accuracy: 9551/10000 (96%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.339668
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.378448
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.382466
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.482458
#
# Train set: Average loss: 0.4054
# Validation set: Average loss: 0.1401, Accuracy: 9579/10000 (96%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.352299
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.436471
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.351128
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.443223
#
# Train set: Average loss: 0.4037
# Validation set: Average loss: 0.1476, Accuracy: 9548/10000 (95%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.396033
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.364802
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.532901
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.268677
#
# Train set: Average loss: 0.4011
# Validation set: Average loss: 0.1616, Accuracy: 9516/10000 (95%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.447248
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.353758
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.290062
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.249107
#
# Train set: Average loss: 0.4033
# Validation set: Average loss: 0.1470, Accuracy: 9540/10000 (95%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.375345
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.441183
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.461674
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.425912
#
# Train set: Average loss: 0.4016
# Validation set: Average loss: 0.1413, Accuracy: 9574/10000 (96%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.305339
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.632980
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.382892
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.351184
#
# Train set: Average loss: 0.4056
# Validation set: Average loss: 0.1423, Accuracy: 9567/10000 (96%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.353877
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.374278
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.307093
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.330862
#
# Train set: Average loss: 0.3966
# Validation set: Average loss: 0.1644, Accuracy: 9524/10000 (95%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.343703
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.522969
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.311424
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.365490
#
# Train set: Average loss: 0.3946
# Validation set: Average loss: 0.1449, Accuracy: 9579/10000 (96%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.394498
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.394563
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.491145
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.370417
#
# Train set: Average loss: 0.4049
# Validation set: Average loss: 0.1515, Accuracy: 9561/10000 (96%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.332507
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.552973
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.461035
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.561010
#
# Train set: Average loss: 0.4053
# Validation set: Average loss: 0.1457, Accuracy: 9561/10000 (96%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.367765
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.327086
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.408706
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.284643
#
# Train set: Average loss: 0.3987
# Validation set: Average loss: 0.1636, Accuracy: 9529/10000 (95%)
#
# Test set: Average loss: 0.1386, Accuracy: 9583/10000 (96%)

# %% [markdown]
# ## Summary
# * *Deep* and *CNN* models with accuracies of 96% and 97% (evaluated on the test subset) perform much better than single-layer *Perceptron* with 92%;
# * The two smallest (and simplest) models appear to be overfitted. To deal with this we need to apply some regularization.
# * Validation subset is evaluated during the training (as opposed to test set, infered *after* the training) in order to tune the model hiperparameters (that describe e.g. the network structure, or training details).
# * A moment to stop trainning is a kind of hipermarameter -- by applying *early stopping* we can avoid overfitting.

# %% [markdown]
# ## Tasks to do
# * apply some regularization technique to *Deep* model in order to avoid overfitting (start with nonzero *weight_decay* in optimizer)
# * try to figure out why the validation loss for *CNN* model turns to be *lower* than the train loss (hint: turn off regularization),
# * **tune one of these models to get the *Test Set Accuracy* > 99%**,
# * plot the *confusion matrix* among all of the classes---which of digits are mostly confused with each other?
# >How to build the confusion matrix?
# > * for example 1st row represents images with "0" digit (*ground truth*), while 1st colum images for which the model *predicts* "0",
# > * this way element _11 is equal to number of images with "0" corectly clasified as "0" (true positives), while _15 means number of images with "0" wrongly calssified as "4", and so on.
